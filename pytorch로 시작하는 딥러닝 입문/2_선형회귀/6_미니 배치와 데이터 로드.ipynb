# %%
# 미니 배치 학습을 하게되면 미니 배치만큼만 가져가서 미니 배치에 대한 대한 비용(cost)를 계산하고, 경사 하강법을 수행
# 에포크(Epoch)는 전체 훈련 데이터가 학습에 한 번 사용된 주기

# 미니 배치 학습에서는 미니 배치의 개수만큼 경사 하강법을 수행해야 전체 데이터가 한 번 전부 사용되어 1 에포크(Epoch)가 된다

# 배치 크기는 보통 2의 제곱수를 사용한다. 
# ex) 2, 4, 8, 16, 32, 64... 
# 그 이유는 CPU와 GPU의 메모리가 2의 배수이므로 
# 배치크기가 2의 제곱수일 경우에 데이터 송수신의 효율을 높일 수 있다고 한다.

# %%
# 이터레이션(Iteration)

# 전체 데이터가 2,000일 때 배치 크기를 200으로 한다면 이터레이션의 수는 총 10개
# 이는 한 번의 에포크 당 매개변수 업데이트가 10번 이루어짐을 의미

# %%
# 파이토치에서는 데이터셋(Dataset)과 데이터로더(DataLoader)를 제공
# 미니 배치 학습, 데이터 셔플(shuffle), 병렬 처리까지 간단히 수행
# 기본적인 사용 방법은 Dataset을 정의하고, 이를 DataLoader에 전달하는 것

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

print(x_train.shape) # torch.Size([5, 3])
print(y_train.shape) # torch.Size([5, 1])

dataset = TensorDataset(x_train, y_train)

dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5) 

nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # enumerate() : 인덱스, 원소로 이루어진 tuple 을 만들어준다
    print('batch_idx : ',batch_idx)
    print('samples : ',samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
        
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# torch.Size([5, 3])
# torch.Size([5, 1])
# batch_idx :  0
# samples :  [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    0/20 Batch 1/3 Cost: 14877.716797
# batch_idx :  1
# samples :  [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch    0/20 Batch 2/3 Cost: 6132.025879
# batch_idx :  2
# samples :  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    0/20 Batch 3/3 Cost: 2717.976562
# batch_idx :  0
# samples :  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch    1/20 Batch 1/3 Cost: 428.130859
# batch_idx :  1
# samples :  [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    1/20 Batch 2/3 Cost: 66.451736
# batch_idx :  2
# samples :  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    1/20 Batch 3/3 Cost: 69.312691
# batch_idx :  0
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    2/20 Batch 1/3 Cost: 4.664128
# batch_idx :  1
# samples :  [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    2/20 Batch 2/3 Cost: 7.840795
# batch_idx :  2
# samples :  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    2/20 Batch 3/3 Cost: 0.650029
# batch_idx :  0
# samples :  [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    3/20 Batch 1/3 Cost: 3.959023
# batch_idx :  1
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    3/20 Batch 2/3 Cost: 1.074886
# batch_idx :  2
# samples :  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    3/20 Batch 3/3 Cost: 0.788626
# batch_idx :  0
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    4/20 Batch 1/3 Cost: 0.355032
# batch_idx :  1
# samples :  [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    4/20 Batch 2/3 Cost: 3.136804
# batch_idx :  2
# samples :  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    4/20 Batch 3/3 Cost: 1.769960
# batch_idx :  0
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch    5/20 Batch 1/3 Cost: 0.744756
# batch_idx :  1
# samples :  [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    5/20 Batch 2/3 Cost: 1.887684
# batch_idx :  2
# samples :  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    5/20 Batch 3/3 Cost: 1.719613
# batch_idx :  0
# samples :  [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    6/20 Batch 1/3 Cost: 1.568413
# batch_idx :  1
# samples :  [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    6/20 Batch 2/3 Cost: 1.411211
# batch_idx :  2
# samples :  [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    6/20 Batch 3/3 Cost: 1.870036
# batch_idx :  0
# samples :  [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    7/20 Batch 1/3 Cost: 1.634491
# batch_idx :  1
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch    7/20 Batch 2/3 Cost: 1.762798
# batch_idx :  2
# samples :  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    7/20 Batch 3/3 Cost: 1.483047
# batch_idx :  0
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    8/20 Batch 1/3 Cost: 0.695539
# batch_idx :  1
# samples :  [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    8/20 Batch 2/3 Cost: 2.650116
# batch_idx :  2
# samples :  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    8/20 Batch 3/3 Cost: 1.615625
# batch_idx :  0
# samples :  [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    9/20 Batch 1/3 Cost: 0.908313
# batch_idx :  1
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    9/20 Batch 2/3 Cost: 3.897643
# batch_idx :  2
# samples :  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    9/20 Batch 3/3 Cost: 0.022672
# batch_idx :  0
# samples :  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   10/20 Batch 1/3 Cost: 0.647820
# batch_idx :  1
# samples :  [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   10/20 Batch 2/3 Cost: 1.501272
# batch_idx :  2
# samples :  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   10/20 Batch 3/3 Cost: 2.965863
# batch_idx :  0
# samples :  [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   11/20 Batch 1/3 Cost: 2.946471
# batch_idx :  1
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   11/20 Batch 2/3 Cost: 0.962195
# batch_idx :  2
# samples :  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   11/20 Batch 3/3 Cost: 1.879061
# batch_idx :  0
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   12/20 Batch 1/3 Cost: 0.717147
# batch_idx :  1
# samples :  [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   12/20 Batch 2/3 Cost: 3.038555
# batch_idx :  2
# samples :  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   12/20 Batch 3/3 Cost: 2.634925
# batch_idx :  0
# samples :  [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   13/20 Batch 1/3 Cost: 1.711873
# batch_idx :  1
# samples :  [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   13/20 Batch 2/3 Cost: 1.560267
# batch_idx :  2
# samples :  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   13/20 Batch 3/3 Cost: 2.185422
# batch_idx :  0
# samples :  [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   14/20 Batch 1/3 Cost: 0.514083
# batch_idx :  1
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   14/20 Batch 2/3 Cost: 2.737333
# batch_idx :  2
# samples :  [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   14/20 Batch 3/3 Cost: 2.291249
# batch_idx :  0
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   15/20 Batch 1/3 Cost: 0.554173
# batch_idx :  1
# samples :  [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   15/20 Batch 2/3 Cost: 4.267074
# batch_idx :  2
# samples :  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   15/20 Batch 3/3 Cost: 0.087475
# batch_idx :  0
# samples :  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   16/20 Batch 1/3 Cost: 0.718264
# batch_idx :  1
# samples :  [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   16/20 Batch 2/3 Cost: 1.972425
# batch_idx :  2
# samples :  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   16/20 Batch 3/3 Cost: 1.687866
# batch_idx :  0
# samples :  [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   17/20 Batch 1/3 Cost: 0.727213
# batch_idx :  1
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   17/20 Batch 2/3 Cost: 2.660136
# batch_idx :  2
# samples :  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   17/20 Batch 3/3 Cost: 2.007478
# batch_idx :  0
# samples :  [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   18/20 Batch 1/3 Cost: 0.628836
# batch_idx :  1
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   18/20 Batch 2/3 Cost: 2.240011
# batch_idx :  2
# samples :  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   18/20 Batch 3/3 Cost: 3.132105
# batch_idx :  0
# samples :  [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   19/20 Batch 1/3 Cost: 0.693779
# batch_idx :  1
# samples :  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   19/20 Batch 2/3 Cost: 2.861038
# batch_idx :  2
# samples :  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   19/20 Batch 3/3 Cost: 1.912846
# batch_idx :  0
# samples :  [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   20/20 Batch 1/3 Cost: 1.555336
# batch_idx :  1
# samples :  [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   20/20 Batch 2/3 Cost: 0.620640
# batch_idx :  2
# samples :  [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   20/20 Batch 3/3 Cost: 2.571115
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[152.7422]], grad_fn=<AddmmBackward>)
